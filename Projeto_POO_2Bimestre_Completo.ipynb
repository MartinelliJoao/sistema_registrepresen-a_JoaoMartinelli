# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# Nome do Aluno: *João Pedro Martinelli Araujo*
#
# Turma: *2B Ti*
#
# Tema Escolhido: *sistema que registre a presença de alunos,*

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Classe para Gerenciamento de Presença de Alunos
class Aluno:
    # Método construtor que inicializa os atributos do aluno
    def __init__(self, nome, matricula, turma):
        self.nome = nome              # Atribui o nome passado ao atributo nome do objeto
        self.matricula = matricula    # Atribui a matrícula passada ao atributo matricula do objeto
        self.turma = turma            # Atribui a turma passada ao atributo turma do objeto

    # Método para exibir os dados do aluno
    def exibir_dados(self):
        print("=== Dados do Aluno ===")              # Imprime um cabeçalho para organizar a saída
        print(f"Nome: {self.nome}")                 # Imprime o nome do aluno armazenado no objeto
        print(f"Matrícula: {self.matricula}")       # Imprime a matrícula do aluno armazenada no objeto
        print(f"Turma: {self.turma}")               # Imprime a turma do aluno armazenada no objeto
        print("======================")               # Imprime uma linha de fechamento para visualização

# Criando dois objetos da classe Aluno com dados inseridos manualmente
# Solicita que o usuário insira os dados no Jupyter

# Primeiro aluno
nome1 = input("Digite o nome do primeiro aluno: ")          # Solicita ao usuário o nome do primeiro aluno
matricula1 = input("Digite a matrícula do primeiro aluno: ")# Solicita a matrícula do primeiro aluno
turma1 = input("Digite a turma do primeiro aluno: ")        # Solicita a turma do primeiro aluno
aluno1 = Aluno(nome1, matricula1, turma1)                    # Cria um objeto Aluno com os dados fornecidos

# Segundo aluno
nome2 = input("Digite o nome do segundo aluno: ")           # Solicita ao usuário o nome do segundo aluno
matricula2 = input("Digite a matrícula do segundo aluno: ") # Solicita a matrícula do segundo aluno
turma2 = input("Digite a turma do segundo aluno: ")         # Solicita a turma do segundo aluno
aluno2 = Aluno(nome2, matricula2, turma2)                    # Cria um objeto Aluno com os dados fornecidos

# Exibindo os dados dos dois alunos
aluno1.exibir_dados()                                        # Chama o método para exibir os dados do primeiro aluno
aluno2.exibir_dados()                                        # Chama o método para exibir os dados do segundo aluno

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Classe principal Aluno, com métodos de ação
class Aluno:
    def __init__(self, nome, matricula, turma):
        self.nome = nome              # Guarda o nome do aluno no atributo 'nome'
        self.matricula = matricula    # Guarda a matrícula do aluno no atributo 'matricula'
        self.turma = turma            # Guarda a turma do aluno no atributo 'turma'
        self.presencas = []           # Inicializa uma lista vazia para armazenar datas de presença

    # Método para exibir dados do aluno
    def exibir_dados(self):
        print(f"Nome: {self.nome}")         # Exibe o nome do aluno
        print(f"Matrícula: {self.matricula}") # Exibe a matrícula do aluno
        print(f"Turma: {self.turma}")       # Exibe a turma do aluno

    # Método para adicionar presença (registrar data)
    def registrar_presenca(self, data):
        self.presencas.append(data)                  # Adiciona a data informada à lista de presenças
        print(f"Presença registrada para {self.nome} na data {data}")  # Confirma o registro da presença

    # Método para exibir todas as presenças registradas
    def exibir_presencas(self):
        if self.presencas:                           # Verifica se há alguma presença registrada
            print(f"Presenças de {self.nome}:")     # Exibe o cabeçalho das presenças do aluno
            for data in self.presencas:              # Percorre todas as datas registradas
                print(f"- {data}")                   # Exibe cada data
        else:
            print(f"Nenhuma presença registrada para {self.nome}")  # Mensagem caso não haja presenças registradas

# Subclasse EstudanteGraduacao que herda de Aluno
class EstudanteGraduacao(Aluno):
    def __init__(self, nome, matricula, turma, curso):
        super().__init__(nome, matricula, turma)  # Chama o construtor da classe pai para inicializar os atributos básicos
        self.curso = curso                         # Atributo exclusivo da subclasse que guarda o curso do estudante

    # Novo método exclusivo da subclasse
    def exibir_curso(self):
        print(f"{self.nome} está matriculado no curso de {self.curso}")  # Exibe o curso do estudante

# Testando com inputs para criar um objeto EstudanteGraduacao e registrar presença

nome = input("Nome do estudante de graduação: ")         # Solicita o nome do estudante
matricula = input("Matrícula: ")                          # Solicita a matrícula
turma = input("Turma: ")                                  # Solicita a turma
curso = input("Curso: ")                                  # Solicita o curso

estudante = EstudanteGraduacao(nome, matricula, turma, curso)  # Cria o objeto EstudanteGraduacao com os dados informados

estudante.exibir_dados()           # Exibe os dados básicos do estudante (nome, matrícula, turma)
estudante.exibir_curso()           # Exibe o curso do estudante

# Registrar uma presença
data_presenca = input("Digite a data da presença (ex: 2025-06-02): ")  # Solicita a data da presença
estudante.registrar_presenca(data_presenca)                            # Registra a presença do estudante na data informada

# Mostrar as presenças
estudante.exibir_presencas()        # Exibe todas as presenças registradas para o estudante

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Classe principal Aluno com encapsulamento e lógica interna
class Aluno:
    def __init__(self, nome, matricula, turma, total_aulas):
        self.nome = nome                    # Guarda o nome do aluno
        self.matricula = matricula          # Guarda a matrícula do aluno
        self.turma = turma                  # Guarda a turma do aluno
        self.__presencas = []               # Atributo privado: lista de datas de presença
        self.total_aulas = total_aulas      # Total de aulas para cálculo da frequência

    def get_presencas(self):
        return self.__presencas             # Retorna a lista privada de presenças

    def set_presencas(self, presencas):
        if isinstance(presencas, list):    # Verifica se o valor passado é uma lista
            self.__presencas = presencas   # Atualiza a lista privada de presenças
        else:
            print("Erro: Presenças devem ser uma lista")  # Mensagem de erro se não for lista

    def registrar_presenca(self, data):
        self.__presencas.append(data)      # Adiciona uma data à lista privada de presenças
        print(f"Presença registrada para {self.nome} na data {data}")  # Confirmação da presença

    def calcular_frequencia(self):
        if self.total_aulas == 0:           # Evita divisão por zero no cálculo
            return 0                        # Retorna zero se total de aulas for zero
        frequencia = (len(self.__presencas) / self.total_aulas) * 100  # Calcula % de presenças
        return frequencia                   # Retorna a frequência calculada

    def exibir_dados(self):
        print(f"Nome: {self.nome}")         # Exibe o nome do aluno
        print(f"Matrícula: {self.matricula}")  # Exibe a matrícula do aluno
        print(f"Turma: {self.turma}")       # Exibe a turma do aluno
        print(f"Frequência: {self.calcular_frequencia():.2f}%")  # Exibe a frequência com 2 casas decimais

# Pedindo dados ao usuário
nome = input("Nome do aluno: ")            # Recebe o nome do aluno
matricula = input("Matrícula: ")            # Recebe a matrícula do aluno
turma = input("Turma: ")                     # Recebe a turma do aluno
total_aulas = int(input("Total de aulas no período: "))  # Recebe o total de aulas e converte para inteiro

aluno = Aluno(nome, matricula, turma, total_aulas)  # Cria o objeto Aluno com os dados fornecidos

while True:
    resp = input("Registrar presença? (s/n): ").lower()  # Pergunta se deseja registrar presença
    if resp == 's':                                       # Se sim, pede a data
        data = input("Digite a data da presença (ex: 2025-06-02): ")
        aluno.registrar_presenca(data)                    # Registra a presença para a data dada
    else:
        break                                            # Sai do laço se a resposta não for 's'

aluno.exibir_dados()                                   # Exibe os dados do aluno e a frequência

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3  # Importa a biblioteca para manipular banco de dados SQLite

# Define a classe principal Aluno
class Aluno:
    def __init__(self, nome, matricula, turma):
        self.nome = nome              # Atributo para guardar o nome do aluno
        self.matricula = matricula    # Atributo para guardar a matrícula do aluno
        self.turma = turma            # Atributo para guardar a turma do aluno

    def exibir_dados(self):
        print(f"Nome: {self.nome}")          # Exibe o nome do aluno
        print(f"Matrícula: {self.matricula}")# Exibe a matrícula do aluno
        print(f"Turma: {self.turma}")        # Exibe a turma do aluno

# Define a subclasse EstudanteGraduacao que herda da classe Aluno
class EstudanteGraduacao(Aluno):
    def __init__(self, nome, matricula, turma, curso):
        super().__init__(nome, matricula, turma)  # Chama o construtor da classe pai para inicializar atributos
        self.curso = curso                         # Atributo exclusivo da subclasse para armazenar o curso

    def exibir_dados(self):
        super().exibir_dados()               # Chama o método exibir_dados da classe pai para mostrar dados básicos
        print(f"Curso: {self.curso}")        # Exibe o curso do estudante (sobrescrevendo o método, polimorfismo)

# Define a classe BancoDados para manipular banco SQLite
class BancoDados:
    def __init__(self, nome_db="presenca_alunos.db"):
        self.conn = sqlite3.connect(nome_db)   # Estabelece conexão com o banco de dados (cria se não existir)
        self.cursor = self.conn.cursor()        # Cria o cursor para executar comandos SQL
        self.criar_tabela()                      # Chama o método para criar tabela, caso não exista

    def criar_tabela(self):  # Comando SQL para criar a tabela 'alunos' com colunas para id, nome, matrícula, turma e curso
        self.cursor.execute("""
            CREATE TABLE IF NOT EXISTS alunos (
                id INTEGER PRIMARY KEY AUTOINCREMENT,  -- Identificador único auto-incrementado
                nome TEXT NOT NULL,                      -- Campo para nome do aluno (não pode ser nulo)
                matricula TEXT NOT NULL,                 -- Campo para matrícula do aluno (não pode ser nulo)
                turma TEXT NOT NULL,                     -- Campo para turma (não pode ser nulo)
                curso TEXT                              -- Campo para curso (pode ser nulo)
            )
        """)
        self.conn.commit()  # Aplica as alterações no banco de dados

    def inserir_aluno(self, aluno):   # Insere um registro de aluno no banco. O curso pode estar presente ou não (None)
        curso = getattr(aluno, 'curso', None)   # Tenta obter o atributo 'curso', se não existir retorna None
        self.cursor.execute("""
            INSERT INTO alunos (nome, matricula, turma, curso) VALUES (?, ?, ?, ?)
        """, (aluno.nome, aluno.matricula, aluno.turma, curso))  # Executa o comando de inserção com valores fornecidos
        self.conn.commit()  # Confirma a operação no banco de dados

    def listar_alunos(self):
        self.cursor.execute("SELECT * FROM alunos")  # Executa comando para buscar todos os alunos
        return self.cursor.fetchall()  # Retorna todos os resultados da consulta como lista de tuplas

    def deletar_aluno(self, matricula):
        self.cursor.execute("DELETE FROM alunos WHERE matricula = ?", (matricula,))  # Deleta aluno pela matrícula
        self.conn.commit()  # Aplica a exclusão no banco de dados

    def fechar(self):
        self.conn.close()  # Fecha a conexão com o banco de dados

# --- Código para testar as funcionalidades ---

banco = BancoDados()  # Cria o objeto que gerencia o banco de dados SQLite

nome = input("Nome do estudante de graduação: ")    # Recebe o nome do estudante
matricula = input("Matrícula: ")                     # Recebe a matrícula
turma = input("Turma: ")                             # Recebe a turma
curso = input("Curso: ")                             # Recebe o curso

estudante = EstudanteGraduacao(nome, matricula, turma, curso)  # Cria um objeto EstudanteGraduacao com os dados

banco.inserir_aluno(estudante)  # Insere o aluno no banco de dados

print("\nDados do estudante inserido:")
estudante.exibir_dados()  # Exibe os dados do estudante usando o método sobrescrito

print("\nLista de todos os alunos no banco:")
alunos = banco.listar_alunos()  # Busca todos os alunos no banco
for a in alunos:
    print(a)  # Exibe cada registro como uma tupla (id, nome, matrícula, turma, curso)

resp = input("\nDeseja excluir algum aluno pelo número da matrícula? (s/n): ").lower()  # Pergunta se deseja excluir aluno
if resp == 's':
    matricula_del = input("Digite a matrícula do aluno a ser excluído: ")  # Pede a matrícula para exclusão
    banco.deletar_aluno(matricula_del)  # Executa a exclusão
    print("Aluno excluído.")

banco.fechar()  # Fecha a conexão com o banco

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import sqlite3  # Biblioteca para manipulação do banco SQLite

# === Classe principal para gerenciar alunos ===
class Aluno:
    def __init__(self, nome, matricula, turma):
        self.__nome = nome             # Atributo privado para nome do aluno
        self.__matricula = matricula   # Atributo privado para matrícula
        self.__turma = turma           # Atributo privado para turma
        self.__presencas = []          # Lista privada para armazenar datas de presença

    # Método getter para nome
    def get_nome(self):
        return self.__nome

    # Método setter para nome
    def set_nome(self, novo_nome):
        self.__nome = novo_nome

    # Método getter para matrícula
    def get_matricula(self):
        return self.__matricula

    # Método setter para matrícula
    def set_matricula(self, nova_matricula):
        self.__matricula = nova_matricula

    # Método getter para turma
    def get_turma(self):
        return self.__turma

    # Método setter para turma
    def set_turma(self, nova_turma):
        self.__turma = nova_turma

    # Método para exibir dados do aluno
    def exibir_dados(self):
        print(f"Nome: {self.__nome}")
        print(f"Matrícula: {self.__matricula}")
        print(f"Turma: {self.__turma}")

    # Método para registrar presença em uma data
    def registrar_presenca(self, data):
        self.__presencas.append(data)
        print(f"Presença registrada para {self.__nome} na data {data}")

    # Método para exibir todas as presenças registradas
    def exibir_presencas(self):
        if self.__presencas:
            print(f"Presenças de {self.__nome}:")
            for data in self.__presencas:
                print(f"- {data}")
        else:
            print(f"Nenhuma presença registrada para {self.__nome}")

# === Subclasse para estudantes de graduação ===
class EstudanteGraduacao(Aluno):
    def __init__(self, nome, matricula, turma, curso):
        super().__init__(nome, matricula, turma)  # Inicializa atributos da classe pai
        self.__curso = curso                       # Atributo privado para curso

    # Getter para curso
    def get_curso(self):
        return self.__curso

    # Setter para curso
    def set_curso(self, novo_curso):
        self.__curso = novo_curso

    # Sobrescreve método para exibir dados, adicionando curso
    def exibir_dados(self):
        super().exibir_dados()                # Exibe dados da classe pai
        print(f"Curso: {self.__curso}")       # Exibe o curso do estudante

# === Classe para manipulação do banco de dados SQLite ===
class BancoDados:
    def __init__(self, nome_db="presenca_alunos.db"):
        self.conn = sqlite3.connect(nome_db)   # Conecta/cria banco SQLite
        self.cursor = self.conn.cursor()        # Cursor para executar comandos SQL
        self.criar_tabela()                      # Garante que a tabela exista

    # Cria tabela 'alunos' caso não exista
    def criar_tabela(self):
        self.cursor.execute("""
            CREATE TABLE IF NOT EXISTS alunos (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                nome TEXT NOT NULL,
                matricula TEXT NOT NULL UNIQUE,
                turma TEXT NOT NULL,
                curso TEXT
            )
        """)
        self.conn.commit()

    # Insere um aluno no banco (pode ser Aluno ou EstudanteGraduacao)
    def inserir_aluno(self, aluno):
        curso = None
        if isinstance(aluno, EstudanteGraduacao):
            curso = aluno.get_curso()
        self.cursor.execute("""
            INSERT INTO alunos (nome, matricula, turma, curso) VALUES (?, ?, ?, ?)
        """, (aluno.get_nome(), aluno.get_matricula(), aluno.get_turma(), curso))
        self.conn.commit()
        print(f"Aluno {aluno.get_nome()} inserido no banco.")

    # Lista todos os alunos
    def listar_alunos(self):
        self.cursor.execute("SELECT * FROM alunos")
        return self.cursor.fetchall()

    # Deleta um aluno pelo número da matrícula
    def deletar_aluno(self, matricula):
        self.cursor.execute("DELETE FROM alunos WHERE matricula = ?", (matricula,))
        self.conn.commit()
        print(f"Aluno com matrícula {matricula} deletado.")

    # Fecha a conexão com o banco
    def fechar(self):
        self.conn.close()

# === Programa principal para interação com o usuário ===
def main():
    banco = BancoDados()  # Cria conexão com banco SQLite

    while True:
        print("\n=== Menu ===")
        print("1 - Inserir estudante de graduação")
        print("2 - Listar todos os alunos")
        print("3 - Deletar aluno por matrícula")
        print("4 - Sair")
        opcao = input("Escolha uma opção: ")

        if opcao == '1':
            nome = input("Nome do estudante: ")
            matricula = input("Matrícula: ")
            turma = input("Turma: ")
            curso = input("Curso: ")
            estudante = EstudanteGraduacao(nome, matricula, turma, curso)
            banco.inserir_aluno(estudante)

        elif opcao == '2':
            alunos = banco.listar_alunos()
            print("\nAlunos cadastrados:")
            for a in alunos:
                print(f"ID: {a[0]}, Nome: {a[1]}, Matrícula: {a[2]}, Turma: {a[3]}, Curso: {a[4]}")

        elif opcao == '3':
            matricula = input("Digite a matrícula do aluno para deletar: ")
            banco.deletar_aluno(matricula)

        elif opcao == '4':
            banco.fechar()
            print("Programa encerrado.")
            break

        else:
            print("Opção inválida, tente novamente.")

# Executa o programa principal se o script for rodado diretamente
if __name__ == "__main__":
    main()
